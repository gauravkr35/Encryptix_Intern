# %%
import pandas as pd

# %%
dataset=pd.read_csv("IRIS.csv")

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dataset.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
dataset.shape
# Out:
# (150, 5)

# %%
dataset.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(3,2))
sns.boxplot(x="sepal_length",data=dataset)
plt.show()

# %%
plt.figure(figsize=(3,2))
sns.boxplot(x="sepal_width",data=dataset)
plt.show()

# %%
plt.figure(figsize=(3,2))
sns.boxplot(x="petal_length",data=dataset)
plt.show()

# %%
plt.figure(figsize=(3,2))
sns.boxplot(x="petal_width",data=dataset)
plt.show()

# %%
import numpy as np

# %%
Q1=np.percentile(dataset["sepal_width"],25)
Q3=np.percentile(dataset["sepal_width"],75)

# %%
Q1,Q3
# Out:
# (2.8, 3.3)

# %%
IQR=Q3-Q1
min_outliers=Q1-1.5*IQR
max_outliers=Q3+1.5*IQR
IQR,min_outliers,max_outliers
# Out:
# (0.5, 2.05, 4.05)

# %%
(dataset['sepal_width']<min_outliers).values.sum()
# Out:
# 1

# %%
(dataset['sepal_width']>max_outliers).values.sum()
# Out:
# 3

# %%
dataset=dataset[(dataset['sepal_width']>min_outliers) & (dataset['sepal_width']<max_outliers)]

# %%
dataset.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    146.000000   146.000000    146.000000   146.000000
# mean       5.856849     3.036986      3.807534     1.219863
# std        0.834093     0.395145      1.757117     0.760365
# min        4.300000     2.200000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.000000      6.900000     2.500000

# %%
plt.figure(figsize=(3,2))
sns.boxplot(x="sepal_width",data=dataset)
plt.show()

# %%
dataset['species'].value_counts()
# Out:
# species
# Iris-virginica     50
# Iris-versicolor    49
# Iris-setosa        47
# Name: count, dtype: int64

# %%
dataset.replace('Iris-virginica',0,inplace=True)
dataset.replace('Iris-versicolor',1,inplace=True)
dataset.replace('Iris-setosa',2,inplace=True)
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_4556\408015607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.replace('Iris-virginica',0,inplace=True)
# C:\Users\gaura\AppData\Local\Temp\ipykernel_4556\408015607.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.replace('Iris-versicolor',1,inplace=True)
# C:\Users\gaura\AppData\Local\Temp\ipykernel_4556\408015607.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        2
# 1             4.9          3.0           1.4          0.2        2
# 2             4.7          3.2           1.3          0.2        2
# 3             4.6          3.1           1.5          0.2        2
# 4             5.0          3.6           1.4          0.2        2
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        0
# 146           6.3          2.5           5.0          1.9        0
# 147           6.5          3.0           5.2          2.0        0
# 148           6.2          3.4           5.4          2.3        0
# 149           5.9          3.0           5.1          1.8        0
#
# [146 rows x 5 columns]

# %%
dataset['species'].value_counts()
# Out:
# species
# 0    50
# 1    49
# 2    47
# Name: count, dtype: int64

# %%
#Iris-virginica     0
#Iris-versicolor    1
#Iris-setosa        2

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        2
# 1             4.9          3.0           1.4          0.2        2
# 2             4.7          3.2           1.3          0.2        2
# 3             4.6          3.1           1.5          0.2        2
# 4             5.0          3.6           1.4          0.2        2
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        0
# 146           6.3          2.5           5.0          1.9        0
# 147           6.5          3.0           5.2          2.0        0
# 148           6.2          3.4           5.4          2.3        0
# 149           5.9          3.0           5.1          1.8        0
#
# [146 rows x 5 columns]

# %%
plt.figure(figsize=(3,2))
sns.kdeplot(x='sepal_length',data=dataset)
plt.show()

# %%
plt.figure(figsize=(3,2))
sns.kdeplot(x='sepal_width',data=dataset)
plt.show()

# %%
plt.figure(figsize=(3,2))
sns.kdeplot(x='petal_length',data=dataset)
plt.show()

# %%
plt.figure(figsize=(3,2))
sns.kdeplot(x='petal_width',data=dataset)
plt.show()

# %%
dataset=dataset.drop_duplicates()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 143 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  143 non-null    float64
#  1   sepal_width   143 non-null    float64
#  2   petal_length  143 non-null    float64
#  3   petal_width   143 non-null    float64
#  4   species       143 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.7 KB

# %%
sns.pairplot(data=dataset , hue='species')
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset['species']

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [143 rows x 4 columns]

# %%
y
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 145    0
# 146    0
# 147    0
# 148    0
# 149    0
# Name: species, Length: 143, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=10)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 148           6.2          3.4           5.4          2.3
# 46            5.1          3.8           1.6          0.2
# 72            6.3          2.5           4.9          1.5
# 27            5.2          3.5           1.5          0.2
# 62            6.0          2.2           4.0          1.0
# ..            ...          ...           ...          ...
# 119           6.0          2.2           5.0          1.5
# 70            5.9          3.2           4.8          1.8
# 16            5.4          3.9           1.3          0.4
# 131           7.9          3.8           6.4          2.0
# 9             4.9          3.1           1.5          0.1
#
# [114 rows x 4 columns]

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 82            5.8          2.7           3.9          1.2
# 20            5.4          3.4           1.7          0.2
# 107           7.3          2.9           6.3          1.8
# 141           6.9          3.1           5.1          2.3
# 44            5.1          3.8           1.9          0.4
# 88            5.6          3.0           4.1          1.3
# 25            5.0          3.0           1.6          0.2
# 110           6.5          3.2           5.1          2.0
# 22            4.6          3.6           1.0          0.2
# 93            5.0          2.3           3.3          1.0
# 1             4.9          3.0           1.4          0.2
# 57            4.9          2.4           3.3          1.0
# 69            5.6          2.5           3.9          1.1
# 74            6.4          2.9           4.3          1.3
# 73            6.1          2.8           4.7          1.2
# ...

# %%
y_test.value_counts()
# Out:
# species
# 1    13
# 2     8
# 0     8
# Name: count, dtype: int64

# %%
y_train.value_counts()
# Out:
# species
# 0    41
# 2    37
# 1    36
# Name: count, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier , plot_tree

# %%
tree=DecisionTreeClassifier(max_depth=4)

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
tree.score(x_test,y_test)*100
# Out:
# 100.0

# %%
tree.score(x_train,y_train)*100
# Out:
# 99.12280701754386

# %%
plt.figure(figsize=(10,10))
plot_tree(tree)
plt.savefig("graph.jpg")
plt.show()

# %%
for i in range(1,20):
    t2=DecisionTreeClassifier(max_depth=i)
    t2.fit(x_train,y_train)
    print(t2.score(x_test,y_test)*100,t2.score(x_train,y_train)*100,  i)
# Out:
# 55.172413793103445 68.42105263157895 1
# 100.0 94.73684210526315 2
# 100.0 96.49122807017544 3
# 100.0 99.12280701754386 4
# 93.10344827586206 100.0 5
# 93.10344827586206 100.0 6
# 100.0 100.0 7
# 100.0 100.0 8
# 93.10344827586206 100.0 9
# 100.0 100.0 10
# 100.0 100.0 11
# 100.0 100.0 12
# 93.10344827586206 100.0 13
# 93.10344827586206 100.0 14
# 100.0 100.0 15
# 93.10344827586206 100.0 16
# 93.10344827586206 100.0 17
# 93.10344827586206 100.0 18
# 100.0 100.0 19

# %%
### max_depth = 4

# %%
from sklearn.metrics import confusion_matrix

# %%
cf2=confusion_matrix(y_test,tree.predict(x_test))
cf2
# Out:
# array([[ 8,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  8]], dtype=int64)

# %%
sns.heatmap(cf2,annot=True)
plt.show()

# %%
tree.predict([[6.5,3.0,5.2,2.0]])
# Out:
# C:\Users\gaura\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
#Iris-virginica     0
#Iris-versicolor    1
#Iris-setosa        2

# %% [markdown]
# # thank you
